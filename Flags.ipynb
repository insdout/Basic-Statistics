# %%
import pandas as pd

# %%
df = pd.read_csv('flags.csv')

# %%
df.head()
# Out:
#              Name  Landmass  Zone  Area  Population  Language  Religion  Bars  \
# 0     Afghanistan         5     1   648          16        10         2     0
# 1         Albania         3     1    29           3         6         6     0
# 2         Algeria         4     1  2388          20         8         2     2
# 3  American-Samoa         6     3     0           0         1         1     0
# 4         Andorra         3     1     0           0         6         0     3
#
#    Stripes  Colors  ...  Saltires  Quarters  Sunstars  Crescent  Triangle  \
# 0        3       5  ...         0         0         1         0         0
# 1        0       3  ...         0         0         1         0         0
# 2        0       3  ...         0         0         1         1         0
# 3        0       5  ...         0         0         0         0         1
# 4        0       3  ...         0         0         0         0         0
#
#    Icon  Animate Text  Topleft  Botright
# ...

# %%
df.describe()
# Out:
#          Landmass        Zone          Area   Population    Language  \
# count  194.000000  194.000000    194.000000   194.000000  194.000000
# mean     3.572165    2.211340    700.046392    23.268041    5.340206
# std      1.553018    1.308274   2170.927932    91.934085    3.496517
# min      1.000000    1.000000      0.000000     0.000000    1.000000
# 25%      3.000000    1.000000      9.000000     0.000000    2.000000
# 50%      4.000000    2.000000    111.000000     4.000000    6.000000
# 75%      5.000000    4.000000    471.250000    14.000000    9.000000
# max      6.000000    4.000000  22402.000000  1008.000000   10.000000
#
#          Religion        Bars     Stripes      Colors         Red  ...  \
# count  194.000000  194.000000  194.000000  194.000000  194.000000  ...
# mean     2.190722    0.453608    1.551546    3.463918    0.788660  ...
# std      2.061167    1.038339    2.328005    1.300154    0.409315  ...
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Landmass', 'Zone', 'Area', 'Population', 'Language',
#        'Religion', 'Bars', 'Stripes', 'Colors', 'Red', 'Green', 'Blue', 'Gold',
#        'White', 'Black', 'Orange', 'Mainhue', 'Circles', 'Crosses', 'Saltires',
#        'Quarters', 'Sunstars', 'Crescent', 'Triangle', 'Icon', 'Animate',
#        'Text', 'Topleft', 'Botright'],
#       dtype='object')

# %%
df.shape
# Out:
# (194, 30)

# %%
df.describe(include=['O'])
# Out:
#                Name Mainhue Topleft Botright
# count           194     194     194      194
# unique          194       8       7        8
# top     Afghanistan     red     red      red
# freq              1      71      56       69

# %%
df["Mainhue"].unique()
# Out:
# array(['green', 'red', 'blue', 'gold', 'white', 'orange', 'black',
#        'brown'], dtype=object)

# %%
df.Area
# Out:
# 0       648
# 1        29
# 2      2388
# 3         0
# 4         0
#        ...
# 189       3
# 190     256
# 191     905
# 192     753
# 193     391
# Name: Area, Length: 194, dtype: int64

# %%
df.Religion.unique()
# Out:
# array([2, 6, 1, 0, 5, 3, 4, 7])

# %%
len(df.Mainhue.unique())
# Out:
# 8

# %%
df.Mainhue.nunique()
# Out:
# 8

# %%
df.Mainhue.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.Mainhue.value_counts()
# Out:
# red       71
# blue      40
# green     31
# white     22
# gold      19
# black      5
# orange     4
# brown      2
# Name: Mainhue, dtype: int64

# %%
df.Mainhue.value_counts().sum()
# Out:
# 194

# %%
df.Mainhue.value_counts()['blue']
# Out:
# 40

# %%
194/2
# Out:
# 97.0

# %%
tb1 = pd.crosstab(df.Circles, df.Bars)
tb1
# Out:
# Bars       0  1  2   3  5
# Circles
# 0        131  6  7  20  1
# 1         27  0  0   0  0
# 2          0  0  0   1  0
# 4          1  0  0   0  0

# %%
tb1[0]
# Out:
# Circles
# 0    131
# 1     27
# 2      0
# 4      1
# Name: 0, dtype: int64

# %%
tb1[0].sum()
# Out:
# 159

# %%
tb1.iloc[0,:]
# Out:
# Bars
# 0    131
# 1      6
# 2      7
# 3     20
# 5      1
# Name: 0, dtype: int64

# %%
tb1.iloc[0,0].sum()
# Out:
# 131

# %%
df.Circles.value_counts()
# Out:
# 0    165
# 1     27
# 4      1
# 2      1
# Name: Circles, dtype: int64

# %%
tb2 = pd.crosstab(df.Crosses, df.Bars)
tb2
# Out:
# Bars       0  1  2   3  5
# Crosses
# 0        133  6  6  21  1
# 1         24  0  1   0  0
# 2          2  0  0   0  0

# %%
total=tb2.sum().sum()

# %%
col_p = tb2.sum(axis=1)/total
col_p
# Out:
# Crosses
# 0    0.860825
# 1    0.128866
# 2    0.010309
# dtype: float64

# %%
row_p = tb2.sum(axis=0)/total
row_p
# Out:
# Bars
# 0    0.819588
# 1    0.030928
# 2    0.036082
# 3    0.108247
# 5    0.005155
# dtype: float64

# %%
import numpy as np
pd.DataFrame(np.expand_dims(np.array(col_p), axis=0).T @ np.expand_dims(np.array(row_p), axis=0))
# Out:
#           0         1         2         3         4
# 0  0.705521  0.026623  0.031061  0.093182  0.004437
# 1  0.105617  0.003986  0.004650  0.013949  0.000664
# 2  0.008449  0.000319  0.000372  0.001116  0.000053

# %%
pd.crosstab(df.Crosses, df.Bars)/total
# Out:
# Bars            0         1         2         3         5
# Crosses
# 0        0.685567  0.030928  0.030928  0.108247  0.005155
# 1        0.123711  0.000000  0.005155  0.000000  0.000000
# 2        0.010309  0.000000  0.000000  0.000000  0.000000
